# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %% [markdown]
# ### auc comparisons of training for inception and the new model

# %%
#new model
new_model='train_batch2012_2.log'#'train_batch2012_2.log'#'train_lung_ds3.log' #'train_batch2012_2.log'#
infile = r"/scratch/sb3923/deep-cancer/logs/"+new_model
step_size =  3504#batch 3504 #ds3 10712#ds2 4849#ds1 1868 #500

auc_new = []
keep_phrases = ["macro AUC"]

with open(infile) as f:
    f = f.readlines()

for line in f:
    for phrase in keep_phrases:
        if phrase in line:
            auc_new.append(line.split(" ")[2][:-2])

print(auc_new)
# Out:
# ['0.772', '0.605', '0.551', '0.579', '0.612', '0.569', '0.631', '0.701', '0.750', '0.677', '0.760', '0.798', '0.639', '0.667', '0.712', '0.663', '0.719', '0.705', '0.748', '0.770', '0.741', '0.741', '0.774', '0.755', '0.708', '0.762', '0.732', '0.779', '0.765', '0.803', '0.758', '0.756', '0.794', '0.755', '0.672', '0.715', '0.720', '0.717', '0.760', '0.744', '0.722', '0.729', '0.750', '0.705', '0.739', '0.762', '0.800', '0.784', '0.739', '0.715', '0.746']

# %%
#inception
keep_phrase = ["macro"]
auc = {}
va = 'validation_lung_batch2012_' #5000 #'validation_lung_ds3_'#

for path, subdirs, files in os.walk('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va):
    for sd in subdirs: 
        if 'test' in sd:
            files = os.listdir('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va+'/'+sd)
            for f in files:
                #print(f)
                if 'out2_roc_data_AvPb_macro' in f:
                    auc[int(sd.split("_")[1][:-1])]=f.split("_")[6]
auc
# Out:
# {500: '0.7504',
#  1000: '0.6649',
#  1500: '0.6895',
#  2000: '0.6249',
#  2500: '0.6965',
#  3000: '0.6677',
#  3500: '0.5749',
#  4000: '0.5602',
#  4500: '0.5124',
#  5000: '0.6330',
#  5500: '0.6403',
#  6000: '0.6699',
#  6500: '0.5863',
#  7000: '0.6424',
#  7500: '0.7040',
#  8000: '0.6675',
#  8500: '0.6794',
#  9000: '0.7053',
#  9500: '0.7277',
#  10000: '0.7155',
#  10500: '0.6935',
#  11000: '0.6889',
#  11500: '0.6847',
#  12000: '0.6892',
#  12500: '0.6806',
#  13000: '0.7308',
#  13500: '0.7896',
#  14000: '0.7428',
#  14500: '0.7585',
#  15000: '0.7629',
#  15500: '0.7555',
#  16000: '0.7522',
#  16500: '0.7578',
#  17000: '0.7485',
#  17500: '0.7531',
#  18000: '0.7601',
#  18500: '0.7597',
#  19000: '0.7770',
#  19500: '0.7703',
#  20000: '0.7370',
#  20500: '0.7217',
#  21000: '0.7001',
#  21500: '0.6411',
#  22000: '0.6396',
#  22500: '0.6338',
#  23000: '0.6551',
#  23500: '0.6655',
#  24000: '0.6685',
#  24500: '0.7192',
#  25000: '0.6700',
#  25500: '0.6700',
#  26000: '0.6341',
#  26500: '0.6237',
#  27000: '0.6384',
#  27500: '0.5980',
#  28000: '0.5663',
#  28500: '0.5198',
#  29000: '0.5146',
#  29500: '0.5011',
#  30000: '0.4970',
#  30500: '0.4991',
#  31000: '0.4960',
#  31500: '0.4910',
#  32000: '0.4956',
#  32500: '0.4909',
#  33000: '0.4918',
#  33500: '0.4963',
#  34000: '0.4859',
#  34500: '0.4962',
#  35000: '0.4966',
#  35500: '0.5121',
#  36000: '0.5031',
#  36500: '0.4891',
#  37000: '0.5163',
#  37500: '0.5018',
#  38000: '0.4924',
#  38500: '0.5062',
#  39000: '0.5201',
#  39500: '0.5254',
#  40000: '0.5529',
#  40500: '0.5558',
#  41000: '0.5589',
#  41500: '0.5525',
#  42000: '0.5573',
#  42500: '0.5538',
#  43000: '0.5476',
#  43500: '0.5487',
#  44000: '0.5575',
#  44500: '0.5466',
#  45000: '0.5507',
#  45500: '0.5511',
#  46000: '0.5554',
#  46500: '0.5538',
#  47000: '0.5567',
#  47500: '0.5625',
#  48000: '0.5562',
#  48500: '0.5537',
#  49000: '0.5741',
#  49500: '0.5760',
#  50000: '0.5723',
#  50500: '0.5856',
#  51000: '0.5820',
#  51500: '0.5817',
#  52000: '0.5845',
#  52500: '0.5811',
#  53000: '0.5826',
#  53500: '0.5871',
#  54000: '0.5940',
#  54500: '0.5936',
#  55000: '0.5928',
#  55500: '0.5812',
#  56000: '0.5825',
#  56500: '0.5881',
#  57000: '0.5965',
#  57500: '0.6019',
#  58000: '0.6153',
#  58500: '0.6106',
#  59000: '0.6186',
#  59500: '0.6112',
#  60000: '0.6218',
#  60500: '0.6279',
#  61000: '0.6089',
#  61500: '0.6021',
#  62000: '0.5847',
#  62500: '0.5743',
#  63000: '0.5857',
#  63500: '0.5729',
#  64000: '0.5818',
#  64500: '0.5825',
#  65000: '0.5795',
#  65500: '0.5824',
#  66000: '0.5839',
#  66500: '0.5826',
#  67000: '0.5778',
#  67500: '0.5698',
#  68000: '0.5732',
#  68500: '0.5605',
#  69000: '0.5461',
#  69500: '0.5325',
#  70000: '0.5281',
#  70500: '0.5362',
#  71000: '0.5188',
#  71500: '0.5188',
#  72000: '0.5168',
#  72500: '0.5111',
#  73000: '0.5119',
#  73500: '0.5202',
#  74000: '0.5165',
#  74500: '0.5221',
#  75000: '0.5385',
#  75500: '0.5583',
#  76000: '0.5584',
#  76500: '0.5558',
#  77000: '0.5524',
#  77500: '0.5642',
#  78000: '0.5743',
#  78500: '0.5782',
#  79000: '0.5750',
#  79500: '0.5899',
#  80000: '0.5923',
#  80500: '0.5966',
#  81000: '0.5991',
#  81500: '0.5960',
#  82000: '0.5980',
#  82500: '0.6053',
#  83000: '0.6057',
#  83500: '0.6142',
#  84000: '0.6087',
#  84500: '0.6343',
#  85000: '0.6329',
#  85500: '0.6354',
#  86000: '0.6408',
#  86500: '0.6422',
#  87000: '0.6519',
#  87500: '0.6552',
#  88000: '0.6691',
#  88500: '0.6626',
#  89000: '0.6669',
#  89500: '0.6591',
#  90000: '0.6674',
#  90500: '0.6694',
#  91000: '0.6729',
#  91500: '0.6754',
#  92000: '0.6710',
#  92500: '0.6695',
#  93000: '0.6643',
#  93500: '0.6618',
#  94000: '0.6570',
#  94500: '0.6562',
#  95000: '0.6504',
#  95500: '0.6597',
#  96000: '0.6606',
#  96500: '0.6716',
#  97000: '0.6824',
#  97500: '0.6889',
#  98000: '0.7063',
#  98500: '0.7137',
#  99000: '0.7077',
#  99500: '0.6954',
#  100000: '0.6914',
#  100500: '0.6998',
#  101000: '0.6972',
#  101500: '0.6956',
#  102000: '0.7028',
#  102500: '0.7038',
#  103000: '0.6881',
#  103500: '0.6913',
#  104000: '0.6894',
#  104500: '0.7067',
#  105000: '0.7137',
#  105500: '0.7037',
#  106000: '0.6951',
#  106500: '0.6819',
#  107000: '0.6854',
#  107500: '0.6881',
#  108000: '0.6909',
#  108500: '0.6903',
#  109000: '0.6962',
#  109500: '0.6999',
#  110000: '0.6979',
#  110500: '0.6980',
#  111000: '0.6937',
#  111500: '0.7001',
#  112000: '0.6961',
#  112500: '0.7072',
#  113000: '0.6934',
#  113500: '0.6981',
#  114000: '0.7013',
#  114500: '0.7034',
#  115000: '0.6961',
#  115500: '0.6942',
#  116000: '0.6780',
#  116500: '0.6647',
#  117000: '0.6621',
#  117500: '0.6648',
#  118000: '0.6665',
#  118500: '0.6651',
#  119000: '0.6715',
#  119500: '0.6849',
#  120000: '0.6934',
#  120500: '0.6926',
#  121000: '0.6924',
#  121500: '0.6927',
#  122000: '0.7035',
#  122500: '0.7067',
#  123000: '0.7097',
#  123500: '0.7139',
#  124000: '0.7216',
#  124500: '0.7312',
#  125000: '0.7317',
#  125500: '0.7401',
#  126000: '0.7410',
#  126500: '0.7371',
#  127000: '0.7314',
#  127500: '0.7306',
#  128000: '0.7229',
#  128500: '0.7218',
#  129000: '0.7224',
#  129500: '0.7184',
#  130000: '0.7152',
#  130500: '0.7265',
#  131000: '0.7315',
#  131500: '0.7312',
#  132000: '0.7410',
#  132500: '0.7459',
#  133000: '0.7509',
#  133500: '0.7488',
#  134000: '0.7478',
#  134500: '0.7398',
#  135000: '0.7282',
#  135500: '0.7274',
#  136000: '0.7232',
#  136500: '0.7196',
#  137000: '0.7215',
#  137500: '0.7263',
#  138000: '0.7281',
#  138500: '0.7256',
#  139000: '0.7089',
#  139500: '0.7051',
#  140000: '0.7028',
#  140500: '0.6993',
#  141000: '0.7018',
#  141500: '0.7031',
#  142000: '0.7052',
#  142500: '0.7075',
#  143000: '0.7266',
#  143500: '0.7271',
#  144000: '0.7286',
#  144500: '0.7199',
#  145000: '0.7302',
#  145500: '0.7255',
#  146000: '0.7312',
#  146500: '0.7348',
#  147000: '0.7302',
#  147500: '0.7266',
#  148000: '0.7200',
#  148500: '0.7151',
#  149000: '0.7149',
#  149500: '0.7170',
#  150000: '0.7180',
#  150500: '0.7167',
#  151000: '0.7207',
#  151500: '0.7119',
#  152000: '0.7156',
#  152500: '0.7179',
#  153000: '0.7057',
#  153500: '0.7062',
#  154000: '0.7094',
#  154500: '0.7136',
#  155000: '0.7236',
#  155500: '0.7258'}

# %%
#inception
keep_phrase = ["macro"]
auc = {}
va = 'validation_auc' #5000

for path, subdirs, files in os.walk('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va):
    for sd in subdirs: 
        if 'test' in sd:
            files = os.listdir('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va+'/'+sd)
            for f in files:
                #print(f)
                if 'out2_roc_data_AvPb_macro' in f:
                    auc[int(sd.split("_")[1][:-1])]=f.split("_")[6]
                    
                    
va = 'validation_auc_85000k' 

for path, subdirs, files in os.walk('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va):
    for sd in subdirs: 
        if 'test' in sd:
            files = os.listdir('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va+'/'+sd)
            for f in files:
                #print(f)
                if 'out2_roc_data_AvPb_macro' in f:
                    auc[int(sd.split("_")[1][:-1])]=f.split("_")[6]
                    
va = 'validation_auc_87000k' 

for path, subdirs, files in os.walk('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va):
    for sd in subdirs: 
        if 'test' in sd:
            files = os.listdir('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va+'/'+sd)
            for f in files:
                #print(f)
                if 'out2_roc_data_AvPb_macro' in f:
                    auc[int(sd.split("_")[1][:-1])]=f.split("_")[6]

va = 'validation_auc_90000k' 

for path, subdirs, files in os.walk('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va):
    for sd in subdirs: 
        if 'test' in sd:
            files = os.listdir('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va+'/'+sd)
            for f in files:
                #print(f)
                if 'out2_roc_data_AvPb_macro' in f:
                    auc[int(sd.split("_")[1][:-1])]=f.split("_")[6]
                    
va = 'validation_auc_130000k' 

for path, subdirs, files in os.walk('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va):
    for sd in subdirs: 
        if 'test' in sd:
            files = os.listdir('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va+'/'+sd)
            for f in files:
                #print(f)
                if 'out2_roc_data_AvPb_macro' in f:
                    auc[int(sd.split("_")[1][:-1])]=f.split("_")[6]

va = 'validation_auc_170000k' 

for path, subdirs, files in os.walk('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va):
    for sd in subdirs: 
        if 'test' in sd:
            files = os.listdir('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va+'/'+sd)
            for f in files:
                #print(f)
                if 'out2_roc_data_AvPb_macro' in f:
                    auc[int(sd.split("_")[1][:-1])]=f.split("_")[6]
                    
                    
va = 'validation_auc_210000k' 

for path, subdirs, files in os.walk('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va):
    for sd in subdirs: 
        if 'test' in sd:
            files = os.listdir('/scratch/sb3923/DeepPATH/DeepPATH_code/01_training/xClasses/'+va+'/'+sd)
            for f in files:
                #print(f)
                if 'out2_roc_data_AvPb_macro' in f:
                    auc[int(sd.split("_")[1][:-1])]=f.split("_")[6]
print(auc)
# Out:
# {128000: '0.9672', 192000: '0.9784', 106500: '0.9600', 85000: '0.9339', 35500: '0.8810', 63500: '0.9330', 197500: '0.9787', 42000: '0.8971', 135000: '0.9719', 20500: '0.8420', 127000: '0.9679', 170500: '0.9764', 105500: '0.9597', 84000: '0.9358', 142000: '0.9742', 62500: '0.9332', 169000: '0.9763', 177500: '0.9762', 19500: '0.8365', 126000: '0.9679', 149000: '0.9760', 104500: '0.9594', 83000: '0.9364', 184500: '0.9759', 61500: '0.9321', 168000: '0.9761', 28000: '0.8329', 18500: '0.8149', 214000: '0.9767', 125000: '0.9673', 191500: '0.9783', 200000: '0.9781', 103500: '0.9596', 212500: '0.9771', 82000: '0.9358', 163000: '0.9737', 60500: '0.9330', 211000: '0.9768', 39000: '0.8849', 134500: '0.9723', 17500: '0.7826', 124000: '0.9654', 170000: '0.9763', 102500: '0.9589', 81000: '0.9342', 141500: '0.9744', 208000: '0.9756', 59500: '0.9339', 38000: '0.8933', 177000: '0.9766', 206500: '0.9760', 16500: '0.7482', 123000: '0.9653', 148500: '0.9758', 101500: '0.9600', 80000: '0.9346', 184000: '0.9759', 58500: '0.9376', 203500: '0.9767', 165000: '0.9748', 27500: '0.8234', 15500: '0.7650', 202000: '0.9763', 122000: '0.9647', 191000: '0.9781', 100500: '0.9592', 200500: '0.9776', 79000: '0.9365', 34500: '0.8626', 57500: '0.9409', 36000: '0.8878', 6000: '0.7695', 142500: '0.9743', 121000: '0.9642', 169500: '0.9763', 99500: '0.9580', 78000: '0.9350', 141000: '0.9741', 196000: '0.9787', 56500: '0.9407', 215000: '0.9765', 35000: '0.8721', 176500: '0.9764', 13500: '0.7812', 120000: '0.9633', 148000: '0.9757', 98500: '0.9560', 193000: '0.9785', 77000: '0.9356', 183500: '0.9760', 55500: '0.9372', 34000: '0.8601', 155000: '0.9746', 140500: '0.9742', 119000: '0.9638', 190500: '0.9785', 97500: '0.9538', 76000: '0.9375', 162000: '0.9717', 54500: '0.9382', 161000: '0.9712', 133500: '0.9707', 139500: '0.9729', 118000: '0.9638', 96500: '0.9527', 75000: '0.9376', 12500: '0.7903', 53500: '0.9379', 160000: '0.9713', 176000: '0.9763', 10500: '0.7803', 117000: '0.9639', 147500: '0.9759', 95500: '0.9512', 74000: '0.9336', 183000: '0.9762', 52500: '0.9326', 159000: '0.9719', 26500: '0.8269', 137500: '0.9719', 116000: '0.9643', 190000: '0.9784', 94500: '0.9514', 73000: '0.9331', 33500: '0.8650', 199500: '0.9779', 51500: '0.9315', 158000: '0.9718', 133000: '0.9699', 136500: '0.9716', 115000: '0.9631', 168500: '0.9762', 93500: '0.9513', 210500: '0.9769', 72000: '0.9348', 140000: '0.9737', 193500: '0.9786', 50500: '0.9293', 157000: '0.9733', 175500: '0.9758', 7500: '0.7769', 114000: '0.9623', 147000: '0.9763', 92500: '0.9501', 198000: '0.9790', 71000: '0.9316', 182500: '0.9766', 49500: '0.9225', 156000: '0.9737', 154000: '0.9745', 6500: '0.7802', 113000: '0.9615', 189500: '0.9780', 209000: '0.9762', 91500: '0.9472', 70000: '0.9278', 33000: '0.8672', 48500: '0.9159', 27000: '0.8180', 4500: '0.7805', 5500: '0.7607', 112000: '0.9606', 40000: '0.8920', 90500: '0.9424', 69000: '0.9263', 11500: '0.7876', 47500: '0.9145', 26000: '0.8302', 132500: '0.9691', 111000: '0.9588', 146500: '0.9765', 89500: '0.9406', 213500: '0.9766', 68000: '0.9287', 182000: '0.9764', 204500: '0.9759', 46500: '0.9134', 212000: '0.9767', 153000: '0.9737', 25500: '0.8317', 3500: '0.7289', 110000: '0.9587', 189000: '0.9782', 88500: '0.9382', 67000: '0.9309', 32500: '0.8632', 45500: '0.9162', 24000: '0.8420', 4000: '0.7505', 207500: '0.9757', 130500: '0.9689', 109000: '0.9565', 167500: '0.9761', 206000: '0.9759', 87500: '0.9348', 66000: '0.9275', 11000: '0.7866', 44500: '0.9095', 151000: '0.9740', 174500: '0.9746', 129500: '0.9679', 203000: '0.9762', 108000: '0.9571', 146000: '0.9766', 86500: '0.9350', 201500: '0.9767', 65000: '0.9304', 181500: '0.9765', 43500: '0.9070', 150000: '0.9748', 25000: '0.8355', 128500: '0.9668', 107000: '0.9594', 188500: '0.9784', 85500: '0.9339', 64000: '0.9324', 32000: '0.8630', 197000: '0.9790', 42500: '0.9002', 21000: '0.8436', 131500: '0.9704', 195500: '0.9785', 127500: '0.9675', 106000: '0.9598', 167000: '0.9760', 84500: '0.9344', 63000: '0.9342', 138500: '0.9717', 415 ...

# %%
#plot both
a=list(auc.values())
t1=list(auc.keys())
t2 = list(range(step_size,(len(auc_new)+1)*step_size,step_size))
b=auc_new
plt.scatter(t1, a, c= 'b',label='inception', s=1) # plotting t, a separately 
plt.scatter(t2, b, c= 'r', label='new model',s=1) # plotting t, b separately 
plt.xlabel('number of steps', fontsize=18)
plt.ylabel('macro auc', fontsize=16)
plt.legend(loc='lower right')
plt.title('lung')
plt.xlim([-5000,200000])
plt.show()

# %%
#14432 steps = 1 epoch
#5000/14432
# Out:
# 0.3464523281596452

# %%
#125000/14432
# Out:
# 8.661308203991132

# %%
14432*12
# Out:
# 173184
