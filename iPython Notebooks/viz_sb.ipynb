# %%
import numpy as np
import math
import random
from PIL import Image, ImageOps, ImageEnhance
import collections
import types
#import new_transforms
import os

"""
Original code from new_transforms.py

Taken directly from https://github.com/pytorch/vision/blob/master/torchvision/transforms.py
Latest update that is not currently deployed to pip.
All credits to the torchvision developers.
"""

# Particulars for this ipython notebook: 
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
# %matplotlib inline



dir_lungTilesNormal = "/beegfs/jmw784/Capstone/LungTilesSorted/Solid_Tissue_Normal/"
dir_lungTilesLUSC = "/beegfs/jmw784/Capstone/LungTilesSorted/TCGA-LUSC/"
dir_lungTilesLUAD = "/beegfs/jmw784/Capstone/LungTilesSorted/TCGA-LUAD/"

# %%
#lung_image_list = os.listdir("/scratch/eff254/Capstone/Data/LungData/c7cf0cf0-d75f-4424-8fd8-8ca6319a56cb")
lung_image_list = os.listdir("/scratch/eff254/Capstone/Data/LungData/0c14abeb-0023-4b75-9f81-3d0cadf37c47")

lung_image_list
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-234237d74fd7> in <module>()
#       1 #lung_image_list = os.listdir("/scratch/eff254/Capstone/Data/LungData/c7cf0cf0-d75f-4424-8fd8-8ca6319a56cb")
# ----> 2 lung_image_list = os.listdir("/scratch/eff254/Capstone/Data/LungData/0c14abeb-0023-4b75-9f81-3d0cadf37c47")
#       3
#       4 lung_image_list
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch/eff254/Capstone/Data/LungData/0c14abeb-0023-4b75-9f81-3d0cadf37c47'

# %%
#files_list

# %%
files_list = os.listdir(dir_lungTilesLUAD)

#cRandomRotate = new_transforms.RandomRotate()
#cJitter = new_transforms.ColorJitter(brightness=0.25, contrast=0.25, saturation=0.25, hue=0.05)
#cVerticalFlip = new_transforms.RandomVerticalFlip()

for repet in range(210,220):
    random = np.random.randint(0,len(files_list))
    #image = Image.open(dir_lungTilesLUAD + 'valid_TCGA-49-6745-01A-01-TS1.f386fbd6-ca0e-4672-b2dc-dbc4c54ef9db_13_14.jpeg')
    image = Image.open(dir_lungTilesLUAD + files_list[random])
    print(files_list[random])
    #modified = cRandomRotate(image)
    #modified = cJitter(modified)
    #modified = cVerticalFlip(modified)
    
    f, (ax1, ax2) = plt.subplots(sharex=True, sharey=False, nrows=1, ncols=2)
    f.set_figheight(4)
    f.set_figwidth(8)
    ax1.imshow(np.asarray(image))
    #ax2.imshow(np.asarray(modified))
    ax1.set_title(files_list[random])
    #ax2.set_title("Modified")
# Out:
# test_TCGA-44-7660-01A-01-TS1.c1e1a47f-0836-4cc8-8dac-b91f51a64fac_19_9.jpeg
# train_TCGA-NJ-A4YP-01A-01-TS1.E45234CC-1B1E-4EEA-925C-AA7969C9C54C_15_6.jpeg
# test_TCGA-44-3398-01A-01-BS1.8347f335-cd9d-46cc-bed5-b28f9dd877a8_36_43.jpeg
# train_TCGA-67-3771-01A-01-BS1.8bcf3f0b-fedd-4eb0-8e29-585ddd074805_31_17.jpeg
# train_TCGA-67-4679-01B-01-BS1.d6a20cd8-c299-427b-83ee-095fae02e488_9_12.jpeg
# valid_TCGA-86-8673-01A-01-TS1.07b1fc57-7059-42ef-87d8-f4c2002bf012_13_77.jpeg
# train_TCGA-91-6830-01A-01-BS1.0ea7ad95-852a-4d1b-9152-0c6582df4d14_1_9.jpeg
# valid_TCGA-86-8673-01A-01-TS1.07b1fc57-7059-42ef-87d8-f4c2002bf012_25_78.jpeg
# valid_TCGA-38-4631-01A-01-BS1.ac8b063c-37ee-4080-aa5e-d13a605dc3bd_17_8.jpeg
# train_TCGA-86-A4P7-01A-01-TSA.7DE944AC-3D14-4E0A-BF05-5E98113C29A8_64_19.jpeg

# %%
import os
os.chdir("/scratch/eff254/Capstone/Data/LungData/")
print(os.path.abspath('test_TCGA-44-6144-01A-01-TS1.0c14abeb-0023-4b75-9f81-3d0cadf37c47.svs'))
# Out:
# /scratch/eff254/Capstone/Data/LungData/test_TCGA-44-6144-01A-01-TS1.0c14abeb-0023-4b75-9f81-3d0cadf37c47.svs

# %%
dirname

sb3923@log-1:/scratch/eff254/Capstone/Data/LungData$ find / -name TCGA-78-7160-01A-01-TS1.96723471-7a98-4954-9b82-a15d4b0a0f65.svs
# Out:
#   File "<ipython-input-10-b160c2fc40ee>", line 3
#     sb3923@log-1:/scratch/eff254/Capstone/Data/LungData$ find / -name 'TCGA-78-7160-01A-01-TS1.96723471-7a98-4954-9b82-a15d4b0a0f65.svs'
#                 ^
# SyntaxError: invalid syntax

# %%
filename
# Out:
# 'TCGA-44-4112-01B-05-BS5.21F5BBD4-EE97-4093-875A-47EC7ABB9FBE.svs'
