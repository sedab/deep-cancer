# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
Image.MAX_IMAGE_PIXELS = 1000000000                                                                                              
import torch
import torchvision
# %matplotlib inline

# %%
d = "/scratch/eff254/Capstone/Data/Lung/"

# %%
f = "/Batch_aa/0000b231-7c05-4e2e-8c9e-6d0675bfbb34/TCGA-55-8514-01A-01-TS1.0e0f5cf3-96e9-4a35-aaed-4340df78d389.svs"

# %%
im = Image.open(d+f)

# %%
im2 = im.crop((0, 0, 100, 100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-7b7f5c12ecfc> in <module>()
# ----> 1 im2 = im.crop((0, 0, 100, 100))
#
# /share/apps/pillow/4.2.1/python3.5/intel/lib/python3.5/site-packages/Pillow-4.2.1-py3.5-linux-x86_64.egg/PIL/Image.py in crop(self, box)
#    1042         """
#    1043
# -> 1044         self.load()
#    1045         if box is None:
#    1046             return self.copy()
#
# /share/apps/pillow/4.2.1/python3.5/intel/lib/python3.5/site-packages/Pillow-4.2.1-py3.5-linux-x86_64.egg/PIL/TiffImagePlugin.py in load(self)
#    1011         if self.use_load_libtiff:
#    1012             return self._load_libtiff()
# -> 1013         return super(TiffImageFile, self).load()
#    1014
#    1015     def load_end(self):
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
#cd '/scratch/sb3923/deep-cancer/logs'



infile = '/scratch/sb3923/deep-cancer/logs/train_lusc_02.log'

# %%
train_loss = []
phrase = "Training Loss"

with open(infile) as f:
    f = f.readlines()

for line in f:
    if phrase in line:
        train_loss.append(line.split(" ")[3][:5])

# %%
step_size=10
t1 = list(range(1,(len(train_loss))*step_size,step_size))
b=train_loss
plt.plot(train_loss[::500], c= 'b',label='inception') # plotting t, a separately 
plt.xlabel('number of steps', fontsize=18)
plt.ylabel('macro auc', fontsize=16)
plt.legend(loc='lower right')
plt.title('All cancer types')
plt.show()

# %%
t1
# Out:
# [1,
#  11,
#  21,
#  31,
#  41,
#  51,
#  61,
#  71,
#  81,
#  91,
#  101,
#  111,
#  121,
#  131,
#  141,
#  151,
#  161,
#  171,
#  181,
#  191,
#  201,
#  211,
#  221,
#  231,
#  241,
#  251,
#  261,
#  271,
#  281,
#  291,
#  301,
#  311,
#  321,
#  331,
#  341,
#  351,
#  361,
#  371,
#  381,
#  391,
#  401,
#  411,
#  421,
#  431,
#  441,
#  451,
#  461,
#  471,
#  481,
#  491,
#  501,
#  511,
#  521,
#  531,
#  541,
#  551,
#  561,
#  571,
#  581,
#  591,
#  601,
#  611,
#  621,
#  631,
#  641,
#  651,
#  661,
#  671,
#  681,
#  691,
#  701,
#  711,
#  721,
#  731,
#  741,
#  751,
#  761,
#  771,
#  781,
#  791,
#  801,
#  811,
#  821,
#  831,
#  841,
#  851,
#  861,
#  871,
#  881,
#  891,
#  901,
#  911,
#  921,
#  931,
#  941,
#  951,
#  961,
#  971,
#  981,
#  991,
#  1001,
#  1011,
#  1021,
#  1031,
#  1041,
#  1051,
#  1061,
#  1071,
#  1081,
#  1091,
#  1101,
#  1111,
#  1121,
#  1131,
#  1141,
#  1151,
#  1161,
#  1171,
#  1181,
#  1191,
#  1201,
#  1211,
#  1221,
# ...
